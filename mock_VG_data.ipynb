# %%
import pandas as pd
import numpy as np

# %%
twitch_streams = pd.read_csv("Most_watched_games_on_Twitch.csv")
video_game_sales = pd.read_csv("vgsales.csv")
steam_data = pd.read_csv("games-features.csv")

# %%
twitch_streams.head()
# Out:
#                          Unnamed: 0  Unnamed: 1  \
# 0                 League of Legends           1
# 1                     Just Chatting           2
# 2                          Fortnite           3
# 3                Grand Theft Auto V           4
# 4  Counter-Strike: Global Offensive           5
#
#                                Game   Watch time  Stream time  Peak viewers  \
# 0                 League of Legends  77530931640   1862302140       1782765
# 1                     Just Chatting  72730827240   1107578340        839576
# 2                          Fortnite  57041617200   4002480600       2331987
# 3                Grand Theft Auto V  41795815320    754766340        389147
# 4  Counter-Strike: Global Offensive  38520066780    880832640        828949
#
#    Peak channels  Streamers  Average viewers  Average channels  \
# 0           8802    1053035           147509              3543
# 1          12126    1168725           138376              2107
# ...

# %%
video_game_sales.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
steam_data.head(50)
# Out:
#     QueryID  ResponseID                                    QueryName  \
# 0        10          10                               Counter-Strike
# 1        20          20                        Team Fortress Classic
# 2        30          30                                Day of Defeat
# 3        40          40                           Deathmatch Classic
# 4        50          50                    Half-Life: Opposing Force
# 5        60          60                                     Ricochet
# 6        70          70                                    Half-Life
# 7        80          80               Counter-Strike: Condition Zero
# 8        80          80               Counter-Strike: Condition Zero
# 9       130         130                        Half-Life: Blue Shift
# 10      220         220                                  Half-Life 2
# 11      240         240                       Counter-Strike: Source
# 12      280         280                            Half-Life: Source
# ...

# %%
steam_data.tail()
# Out:
#        QueryID  ResponseID         QueryName      ResponseName  ReleaseDate  \
# 13352   567660      567660     Baseball Riot     Baseball Riot  Jan 17 2017
# 13353   567860      567860         Passage 4         Passage 4  Dec 13 2016
# 13354   567940      567940        Piximalism        Piximalism  Sep 26 2019
# 13355   568150      568150        Technoball        Technoball  Dec 12 2016
# 13356   559250      559250  Ghostlight Manor  Ghostlight Manor  Dec 12 2016
#
#        RequiredAge  DemoCount  DeveloperCount  DLCCount  Metacritic  ...  \
# 13352            0          0               1         0           0  ...
# 13353            0          0               1         0           0  ...
# 13354            0          0               1         0           0  ...
# 13355            0          0               1         0           0  ...
# 13356            0          0               1         0           0  ...
#
#                           LegalNotice  \
# ...

# %%
len(steam_data)
# Out:
# 13357

# %%
len(steam_data.columns)
# Out:
# 52

# %%
len(video_game_sales)
# Out:
# 16598

# %%
steam_data = steam_data.drop(['RequiredAge', 'DemoCount', 'DLCCount', 'LegalNotice', 'PCReqsHaveMin', 'PCReqsHaveRec',
       'LinuxReqsHaveMin', 'LinuxReqsHaveRec', 'MacReqsHaveMin',
       'MacReqsHaveRec', 'SupportEmail', 'SupportURL', 'PCMinReqsText', 'PCRecReqsText', 'LinuxMinReqsText',
       'LinuxRecReqsText', 'MacMinReqsText', 'MacRecReqsText', 'SteamSpyOwners', 'SteamSpyOwnersVariance', 'SteamSpyPlayersEstimate',
       'SteamSpyPlayersVariance', 'HeaderImage', 'ResponseID','DRMNotice', 'ResponseName'], axis=1)
steam_data.head()
# Out:
#    QueryID                  QueryName ReleaseDate  DeveloperCount  Metacritic  \
# 0       10             Counter-Strike  Nov 1 2000               1          88
# 1       20      Team Fortress Classic  Apr 1 1999               1           0
# 2       30              Day of Defeat  May 1 2003               1          79
# 3       40         Deathmatch Classic  Jun 1 2001               1           0
# 4       50  Half-Life: Opposing Force  Nov 1 1999               1           0
#
#    MovieCount  PackageCount  RecommendationCount  PublisherCount  \
# 0           0             1                68991               1
# 1           0             1                 2439               1
# 2           0             1                 2319               1
# 3           0             1                  888               1
# 4           0             1                 2934               1
#
#    ScreenshotCount  ...  PriceInitial  PriceFinal  \
# 0               13  ...          9.99        9.99
# ...

# %%
steam_data.tail()
# Out:
#        QueryID         QueryName  ReleaseDate  DeveloperCount  Metacritic  \
# 13352   567660     Baseball Riot  Jan 17 2017               1           0
# 13353   567860         Passage 4  Dec 13 2016               1           0
# 13354   567940        Piximalism  Sep 26 2019               1           0
# 13355   568150        Technoball  Dec 12 2016               1           0
# 13356   559250  Ghostlight Manor  Dec 12 2016               1           0
#
#        MovieCount  PackageCount  RecommendationCount  PublisherCount  \
# 13352           1             0                    0               1
# 13353           1             0                    0               1
# 13354           1             0                    0               1
# 13355           1             0                    0               1
# 13356           1             0                    0               1
#
#        ScreenshotCount  ...  PriceInitial  PriceFinal  \
# ...

# %%
print(steam_data.columns)
# Out:
# Index(['QueryID', 'QueryName', 'ReleaseDate', 'DeveloperCount', 'Metacritic',
#        'MovieCount', 'PackageCount', 'RecommendationCount', 'PublisherCount',
#        'ScreenshotCount', 'AchievementCount', 'AchievementHighlightedCount',
#        'ControllerSupport', 'IsFree', 'FreeVerAvail', 'PurchaseAvail',
#        'SubscriptionAvail', 'PlatformWindows', 'PlatformLinux', 'PlatformMac',
#        'CategorySinglePlayer', 'CategoryMultiplayer', 'CategoryCoop',
#        'CategoryMMO', 'CategoryInAppPurchase', 'CategoryIncludeSrcSDK',
#        'CategoryIncludeLevelEditor', 'CategoryVRSupport', 'GenreIsNonGame',
#        'GenreIsIndie', 'GenreIsAction', 'GenreIsAdventure', 'GenreIsCasual',
#        'GenreIsStrategy', 'GenreIsRPG', 'GenreIsSimulation',
#        'GenreIsEarlyAccess', 'GenreIsFreeToPlay', 'GenreIsSports',
#        'GenreIsRacing', 'GenreIsMassivelyMultiplayer', 'PriceCurrency',
#        'PriceInitial', 'PriceFinal', 'AboutText', 'Background', 'ShortDescrip',
# ...

# %%
len(steam_data.columns)
# Out:
# 52

# %%
#frames = [video_game_sales, steam_data]
#video_game_data = pd.concat(frames)
#video_game_data

# %%
steam_data = steam_data.to_csv('steam_data.csv')
