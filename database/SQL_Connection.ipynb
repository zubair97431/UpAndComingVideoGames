# %%
# -- SQL_Connection to local Postgres SQL Database

# Resources for connection help:
# -- https://medium.com/analytics-vidhya/postgresql-integration-with-jupyter-notebook-deb97579a38d
# -- https://overiq.com/sqlalchemy-101/installing-sqlalchemy-and-connecting-to-database/

# Load ipython-sql to use and store SQL commands in notebook
# %load_ext sql

# %%
# Import dependencies 
import pandas as pd 
import numpy as np 
from sqlalchemy import create_engine

# Import connection string from config file
from config import db_password

# %%
# Connect sqlalchemy to database using connection string

db_string = f"postgres://postgres:{db_password}@localhost:5433/SteamDB"

# -- Alternate db_string for engine connection, update host and DB connection as needed. 
# db_string = f"postgres://postgres:{db_password}@127.0.0.1:54642/SteamDB"

engine = create_engine(db_string)

print(engine)
# Out:
# Engine(postgres://postgres:***@localhost:5433/SteamDB)

# %%
# Create Popular Tags dataframe from SQL table

popular_tags = pd.read_sql('SELECT * FROM populartags', engine)

popular_tags.head()
# Out:
#                         game_name  website_rating  \
# 0                     60 SECONDS!              70
# 1                    7 WONDERS II              60
# 2  7 WONDERS OF THE ANCIENT WORLD              30
# 3                         80 DAYS              50
# 4    9TH COMPANY: ROOTS OF TERROR              45
#
#                                         popular_tags  tag_1980s  tag_1990s  \
# 0  Survival,Post-apocalyptic,Singleplayer,Strateg...      False      False
# 1                 Casual,Puzzle,Match 3,Singleplayer      False      False
# 2        Casual,Strategy,Puzzle,Match 3,Singleplayer      False      False
# 3  Adventure,Story Rich,Choices Matter,Choose You...      False      False
# 4    Strategy,RTS,Military,War,Cold War,Singleplayer      False      False
#
#    tag_2_5d  tag_2d  tag_2d_fighter  tag_3d  tag_3d_platformer  ...  \
# 0     False   False           False   False              False  ...
# 1     False   False           False   False              False  ...
# 2     False   False           False   False              False  ...
# 3     False   False           False   False              False  ...
# 4     False   False           False   False              False  ...
#
#    video_production  violent  visual_novel  voxel  walking_simulator    war  \
# 0             False    False         False  False              False   True
# 1             False    False         False  False              False  False
# 2             False    False         False  False              False  False
# 3             False    False         False  False              False  False
# 4             False    False         False  False              False   True
#
#    wargame  web_publishing  world_war_ii  zombies
# 0    False           False         False    False
# 1    False           False         False    False
# 2    False           False         False    False
# 3    False           False         False    False
# 4    False           False         False    False
#
# [5 rows x 227 columns]

# %%
# Create Game Genre dataframe from SQL table 

genre_df = pd.read_sql('SELECT * FROM gamegenres', engine)

genre_df.head()
# Out:
#                         game_name  website_rating  \
# 0                     60 Seconds!              70
# 1                    7 Wonders II              60
# 2  7 Wonders of the Ancient World              30
# 3                         80 Days              50
# 4                    A Bird Story              75
#
#                                         genre  action  adventure  casual  \
# 0  Adventure,Casual,Indie,Simulation,Strategy   False       True    True
# 1                                      Casual   False      False    True
# 2                             Casual,Strategy   False      False    True
# 3                    Adventure,Indie,Strategy   False       True   False
# 4                         Adventure,Indie,RPG   False       True   False
#
#    design_and_illustration  early_access  free_to_play  indie  \
# 0                    False         False         False   True
# 1                    False         False         False  False
# 2                    False         False         False  False
# 3                    False         False         False   True
# 4                    False         False         False   True
#
#    massively_multiplayer    rpg  racing  simulation  sports  strategy  \
# 0                  False  False   False        True   False      True
# 1                  False  False   False       False   False     False
# 2                  False  False   False       False   False      True
# 3                  False  False   False       False   False      True
# 4                  False   True   False       False   False     False
#
#    utilities
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
