# %%
import pandas as pd
import numpy as np

# %%
twitch_streams = pd.read_csv("Most_watched_games_on_Twitch.csv")
video_game_sales = pd.read_csv("vgsales.csv")
steam_data = pd.read_csv("steam_games.csv")

# %%
twitch_streams.head()
# Out:
#                          Unnamed: 0  Unnamed: 1  \
# 0                 League of Legends           1
# 1                     Just Chatting           2
# 2                          Fortnite           3
# 3                Grand Theft Auto V           4
# 4  Counter-Strike: Global Offensive           5
#
#                                Game   Watch time  Stream time  Peak viewers  \
# 0                 League of Legends  77530931640   1862302140       1782765
# 1                     Just Chatting  72730827240   1107578340        839576
# 2                          Fortnite  57041617200   4002480600       2331987
# 3                Grand Theft Auto V  41795815320    754766340        389147
# 4  Counter-Strike: Global Offensive  38520066780    880832640        828949
#
#    Peak channels  Streamers  Average viewers  Average channels  \
# 0           8802    1053035           147509              3543
# 1          12126    1168725           138376              2107
# ...

# %%
video_game_sales.head(50)
# Out:
#     Rank                                          Name Platform    Year  \
# 0      1                                    Wii Sports      Wii  2006.0
# 1      2                             Super Mario Bros.      NES  1985.0
# 2      3                                Mario Kart Wii      Wii  2008.0
# 3      4                             Wii Sports Resort      Wii  2009.0
# 4      5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5      6                                        Tetris       GB  1989.0
# 6      7                         New Super Mario Bros.       DS  2006.0
# 7      8                                      Wii Play      Wii  2006.0
# 8      9                     New Super Mario Bros. Wii      Wii  2009.0
# 9     10                                     Duck Hunt      NES  1984.0
# 10    11                                    Nintendogs       DS  2005.0
# 11    12                                 Mario Kart DS       DS  2005.0
# ...

# %%
steam_data.head(50)
# Out:
#                                                   url   types  \
# 0     https://store.steampowered.com/app/379720/DOOM/     app
# 1   https://store.steampowered.com/app/578080/PLAY...     app
# 2   https://store.steampowered.com/app/637090/BATT...     app
# 3     https://store.steampowered.com/app/221100/DayZ/     app
# 4   https://store.steampowered.com/app/8500/EVE_On...     app
# 5   https://store.steampowered.com/bundle/5699/Gra...  bundle
# 6   https://store.steampowered.com/app/601150/Devi...     app
# 7   https://store.steampowered.com/app/477160/Huma...     app
# 8   https://store.steampowered.com/app/644930/They...     app
# 9   https://store.steampowered.com/app/774241/Warh...     app
# 10  https://store.steampowered.com/app/527230/For_...     app
# 11  https://store.steampowered.com/app/567640/Dang...     app
# 12    https://store.steampowered.com/app/323370/TERA/     app
# 13  https://store.steampowered.com/app/393080/Call...     app
# ...

# %%
steam_data.tail()
# Out:
#                                                      url types  \
# 40828  https://store.steampowered.com/app/899836/Rock...   app
# 40829  https://store.steampowered.com/app/899832/Rock...   app
# 40830  https://store.steampowered.com/app/906840/Fant...   app
# 40831  https://store.steampowered.com/app/906635/Mega...   app
# 40832  https://store.steampowered.com/app/908000/Stor...   app
#
#                                                     name  \
# 40828  Rocksmith® 2014 Edition – Remastered – Sabaton...
# 40829  Rocksmith® 2014 Edition – Remastered – Stone T...
# 40830  Fantasy Grounds - Quests of Doom 4: A Midnight...
# 40831                       Mega Man X5 Sound Collection
# 40832                                   Stories In Stone
#
#                                             desc_snippet recent_reviews  \
# 40828                                                NaN            NaN
# 40829                                                NaN            NaN
# ...

# %%
len(steam_data)
# Out:
# 40833

# %% [markdown]
# ### With 40,833 rows, the "steam_data" dataset is large enough for us to obtain some interesting findings with our Machine Learning Model. We will need to drop a few columns though.

# %%
len(twitch_streams)
# Out:
# 100

# %% [markdown]
# ### The "twitch_streams" dataset only has 100 rows, which makes it VERY small dataset.

# %%
len(steam_data.columns)
# Out:
# 20

# %%
len(video_game_sales)
# Out:
# 16598

# %% [markdown]
# ###  The "video_game_sales" dataset has 16,598 rows, which also makes it a good candidate for our modeling.
# ### Now, we must clean our "steam_data" by dropping any columns that contain information that we are not trying to analyze.

# %%
steam_data_new = steam_data.drop(["url", "types", "desc_snippet", "languages", "recent_reviews", "release_date", "developer", "publisher", "achievements", "game_description", "mature_content", "minimum_requirements", "recommended_requirements", "original_price", "discount_price"], axis=1)
steam_data_new.head()
# Out:
#                             name  \
# 0                           DOOM
# 1  PLAYERUNKNOWN'S BATTLEGROUNDS
# 2                     BATTLETECH
# 3                           DayZ
# 4                     EVE Online
#
#                                          all_reviews  \
# 0  Very Positive,(42,550),- 92% of the 42,550 use...
# 1  Mixed,(836,608),- 49% of the 836,608 user revi...
# 2  Mostly Positive,(7,030),- 71% of the 7,030 use...
# 3  Mixed,(167,115),- 61% of the 167,115 user revi...
# 4  Mostly Positive,(11,481),- 74% of the 11,481 u...
#
#                                         popular_tags  \
# 0  FPS,Gore,Action,Demons,Shooter,First-Person,Gr...
# 1  Survival,Shooter,Multiplayer,Battle Royale,PvP...
# 2  Mechs,Strategy,Turn-Based,Turn-Based Tactics,S...
# 3  Survival,Zombies,Open World,Multiplayer,PvP,Ma...
# 4  Space,Massively Multiplayer,Sci-fi,Sandbox,MMO...
#
#                                         game_details  \
# 0  Single-player,Multi-player,Co-op,Steam Achieve...
# ...

# %%
steam_data_new.tail()
# Out:
#                                                     name all_reviews  \
# 40828  Rocksmith® 2014 Edition – Remastered – Sabaton...         NaN
# 40829  Rocksmith® 2014 Edition – Remastered – Stone T...         NaN
# 40830  Fantasy Grounds - Quests of Doom 4: A Midnight...         NaN
# 40831                       Mega Man X5 Sound Collection         NaN
# 40832                                   Stories In Stone         NaN
#
#                                             popular_tags  \
# 40828                                  Casual,Simulation
# 40829                                  Casual,Simulation
# 40830  RPG,Indie,Strategy,Software,Turn-Based,Fantasy...
# 40831                                             Action
# 40832                                      RPG,Adventure
#
#                                             game_details               genre
# 40828  Single-player,Shared/Split Screen,Downloadable...   Casual,Simulation
# ...

# %%
print(steam_data_new.columns)
# Out:
# Index(['name', 'all_reviews', 'popular_tags', 'game_details', 'genre'], dtype='object')

# %%
len(steam_data_new.columns)
# Out:
# 5

# %% [markdown]
# ### Download as csv file.

# %%
steam_data_new.to_csv('new_steam_data.csv')
