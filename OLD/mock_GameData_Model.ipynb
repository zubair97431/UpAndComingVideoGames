# %%
import pandas as pd
import numpy as np

# %%
# Read from mockup data 
mockup_gamedata = pd.read_csv("mockupGameData.csv")

# %%
mockup_gamedata.head()
# Out:
#                       Name ReleaseDate  Price  GlobalSales  Metacritic  \
# 0                   Halo 4  Nov 1 2000  49.99        82.74          88
# 1         Kingdom Hearts 3  Apr 1 1999  50.99        40.24           0
# 2        Tales of Berseria  May 1 2003  29.99        35.82          79
# 3  The World Ends With You  Jun 1 2001  19.99        33.00          50
# 4          Animal Crossing  Nov 1 1999  59.99        31.37          80
#
#    ReccomendationCount  CopiesSold  PlatformWindows  PlatformLinux  \
# 0                68991     9140731                1              1
# 1                 2439      753627                0              0
# 2                 2319     1709740                1              1
# 3                  888      789676                0              0
# 4                 2934      705741                0              0
#
#    PlatformMac  ...  MMO  GenreIndie  GenreAction  GenreAdventure  \
# ...
